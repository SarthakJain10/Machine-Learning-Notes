# %% [markdown]
# # Standardization

# %% [markdown]
# -> it brings down the mean to zero

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as img 

plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/b334a708a5c74c9ea35af84de1bb085b.png'))

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/7f7da550575d4c908e654616418de055.png'))
