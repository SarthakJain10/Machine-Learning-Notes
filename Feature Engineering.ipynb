# %% [markdown]
# *Feature engineering is the process of using domain knowledge to extract features from raw
# data. These features can be used to improve the performance of machine learning algorithms.*

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as img 

plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/c1fa2a43528b41a18de9887ceb77c67a.png'))

# %% [markdown]
# ## 1. Feature Transformation

# %% [markdown]
# ### 1.1 Missing Values Imputation

# %% [markdown]
# Filling the missing values with different methods

# %% [markdown]
# ### 1.2 Handling Categorical Values

# %% [markdown]
# performing one-hot-encoding ad other methods

# %% [markdown]
# ### 1.3 Outlier Detection

# %% [markdown]
# detecting and removing outliers in dataset

# %% [markdown]
# ### 1.4 Feature Scaling

# %% [markdown]
# using techniques like standarisation and normalization to scale down the data

# %% [markdown]
# ## 2. Feature Construction

# %% [markdown]
# creating new feature from existing feature
# like combining two feature to make a new feature

# %% [markdown]
# ## 3. Feature Selection

# %% [markdown]
# removing unwanted features/columns from dataset

# %% [markdown]
# ## 4. Feature Extraction

# %% [markdown]
# baad mai seekh liyo abhi yaad nhi kya tha
