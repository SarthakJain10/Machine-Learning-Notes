# %% [markdown]
# ## 1. Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(tips['total_bill'],tips['tip'],hue=df['sex'],style=df['smoker'],size=df['size'])

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as img 

plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/3d9197ca43ab48ea8a9ddf9bf8ca9c96.png') )

# %% [markdown]
# ## 2. Bar Plot (Numerical - Categorical)

# %%
sns.barplot(titanic['Pclass'],titanic['Age'],hue=titanic['Sex'])

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/5d05baa6d87c4495bc6aff06e17e4dbc.png') )

# %% [markdown]
# ## 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(titanic['Sex'],titanic['Age'],hue=titanic['Survived'])

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/413ceb033566437c978908270e97e85a.png') )

# %% [markdown]
# ## 4. Distplot (Numerical - Categorical)

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/b9d7fc0dbe574671a9718618d3c20abd.png') )

# %% [markdown]
# ## 5. HeatMap (Categorical - Categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/6a4d19cf077a4e25b132862f8e40aace.png') )

# %% [markdown]
# ## 6. ClusterMap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/773074f8f9634fbbbf6d42b1d0fbebfc.png') )

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/441071401a9e456cbfe25068b1a39a81.png') )

# %% [markdown]
# ## 7. Pairplot

# %%
sns.pairplot(iris,hue='species')

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/9dae52cb81a141e8a3d94dd95bf0b3eb.png') )

# %% [markdown]
# ## 8. Lineplot (Numerical - Numerical)

# %%
sns.lineplot(new['year'],new['passengers'])

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/55dd1bdf9d2845ad9d679af83e47d684.png') )
