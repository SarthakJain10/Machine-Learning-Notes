# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ## 1. Countplot

# %% [markdown]
# analyse the subclasses of that feature

# %%
sns.countplot(df['column_name'])

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as img 

plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/066c1e7e224c425a8845725063076926.png') )

# %% [markdown]
# ## 2. PieChart

# %%
df['column_name'].value_count().plot(kind='pie', autopct='%.2f')

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/0ff90a5ba7a74584b655bfc8dcf524ed.png') )

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ## 1. Histogram

# %% [markdown]
# shows the flow of data

# %%
plt.hist(df['column_name'], bins=5)

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/1b41001493c843b2b381681bc8e5972a.png') )

# %% [markdown]
# ## 2. Distplot

# %% [markdown]
# it just plot KDE (kernel density estimation)
#
# it tell the probability stats

# %%
sns.distplot(df['column_name'])

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/6c7de5493e7c441891c133d7e29f6eeb.png') )

# %% [markdown]
# ## 3. Boxplot

# %% [markdown]
# gives 5 number summary
#
# helps to find **Outliers**

# %%
sns.boxplot(df['column_name'])

# %%
plt.imshow(img.imread('/home/sarthak/.config/joplin-desktop/resources/2b3446a2f2804d20a9426f41e7579f81.png') )

# %% [markdown]
# ## 4. Other

# %%
df['column_name'].min()

# %%
df['column_name'].max()

# %%
df['column_name'].mean()

# %%
df['column_name'].skew()
